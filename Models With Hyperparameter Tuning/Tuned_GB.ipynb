# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.6.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.17.2)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.44)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.4)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# Downloading optuna-4.6.0-py3-none-any.whl (404 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.7/404.7 kB 4.7 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, optuna
# Successfully installed colorlog-6.10.1 optuna-4.6.0

# %%
import optuna
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# %%
# 1. Load Data
X_train = pd.read_csv('cleveland_X_train_processed.csv')
X_test = pd.read_csv('cleveland_X_test_processed.csv')
y_train = pd.read_csv('cleveland_y_train_processed.csv').values.ravel()
y_test = pd.read_csv('cleveland_y_test_processed.csv').values.ravel()

# %%
# 2. Define Optuna Objective Function
def objective(trial):
    # Search space for hyperparameters
    # max_depth: usually small for boosting (e.g., 3-10)
    max_depth = trial.suggest_int('max_depth', 3, 20)

    # learning_rate: usually between 0.01 and 0.3, log=True allows exploring smaller values effectively
    learning_rate = trial.suggest_float('learning_rate', 0.001, 0.3, log=True)

    # random_state: tuning seed
    random_state = trial.suggest_int('random_state', 0, 100)

    # Initialize Gradient Boosting with suggested parameters
    gb = GradientBoostingClassifier(
        max_depth=max_depth,
        learning_rate=learning_rate,
        random_state=random_state
    )

    # 10-Fold Cross-Validation
    kf = KFold(n_splits=10, shuffle=True, random_state=42)

    # n_jobs=-1 uses all CPU cores
    scores = cross_val_score(gb, X_train, y_train, cv=kf, scoring='accuracy', n_jobs=-1)

    return scores.mean()

# %%
# Create and run the study
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)
# Out:
# [I 2025-12-04 07:58:59,074] A new study created in memory with name: no-name-c6b50d19-658b-48e1-880e-c3fe26a31db8
# [I 2025-12-04 07:59:12,165] Trial 0 finished with value: 0.7142857142857143 and parameters: {'max_depth': 7, 'learning_rate': 0.001258888719655872, 'random_state': 87}. Best is trial 0 with value: 0.7142857142857143.
# [I 2025-12-04 07:59:17,807] Trial 1 finished with value: 0.7506493506493507 and parameters: {'max_depth': 7, 'learning_rate': 0.0019334389454616012, 'random_state': 94}. Best is trial 1 with value: 0.7506493506493507.
# [I 2025-12-04 07:59:23,647] Trial 2 finished with value: 0.7506493506493506 and parameters: {'max_depth': 16, 'learning_rate': 0.034082850908794614, 'random_state': 100}. Best is trial 1 with value: 0.7506493506493507.
# [I 2025-12-04 07:59:29,038] Trial 3 finished with value: 0.7599567099567099 and parameters: {'max_depth': 9, 'learning_rate': 0.006301244396060899, 'random_state': 72}. Best is trial 3 with value: 0.7599567099567099.
# [I 2025-12-04 07:59:32,001] Trial 4 finished with value: 0.7311688311688311 and parameters: {'max_depth': 8, 'learning_rate': 0.014691355744638843, 'random_state': 25}. Best is trial 3 with value: 0.7599567099567099.
# [I 2025-12-04 07:59:34,189] Trial 5 finished with value: 0.7454545454545455 and parameters: {'max_depth': 5, 'learning_rate': 0.004665495178153908, 'random_state': 64}. Best is trial 3 with value: 0.7599567099567099.
# [I 2025-12-04 07:59:37,256] Trial 6 finished with value: 0.7551948051948052 and parameters: {'max_depth': 9, 'learning_rate': 0.005806212059471882, 'random_state': 33}. Best is trial 3 with value: 0.7599567099567099.
# [I 2025-12-04 07:59:39,917] Trial 7 finished with value: 0.7601731601731602 and parameters: {'max_depth': 4, 'learning_rate': 0.02713190953068309, 'random_state': 27}. Best is trial 7 with value: 0.7601731601731602.
# [I 2025-12-04 07:59:42,796] Trial 8 finished with value: 0.7506493506493506 and parameters: {'max_depth': 14, 'learning_rate': 0.005243766663959568, 'random_state': 0}. Best is trial 7 with value: 0.7601731601731602.
# [I 2025-12-04 07:59:45,582] Trial 9 finished with value: 0.7554112554112553 and parameters: {'max_depth': 10, 'learning_rate': 0.0026533721706207096, 'random_state': 59}. Best is trial 7 with value: 0.7601731601731602.
# [I 2025-12-04 07:59:46,792] Trial 10 finished with value: 0.7783549783549784 and parameters: {'max_depth': 3, 'learning_rate': 0.24204991783562543, 'random_state': 39}. Best is trial 10 with value: 0.7783549783549784.
# [I 2025-12-04 07:59:48,016] Trial 11 finished with value: 0.7597402597402598 and parameters: {'max_depth': 3, 'learning_rate': 0.2533927712443753, 'random_state': 38}. Best is trial 10 with value: 0.7783549783549784.
# [I 2025-12-04 07:59:49,213] Trial 12 finished with value: 0.7597402597402597 and parameters: {'max_depth': 3, 'learning_rate': 0.2067038102139538, 'random_state': 13}. Best is trial 10 with value: 0.7783549783549784.
# [I 2025-12-04 07:59:53,060] Trial 13 finished with value: 0.7554112554112553 and parameters: {'max_depth': 13, 'learning_rate': 0.07445931817485742, 'random_state': 46}. Best is trial 10 with value: 0.7783549783549784.
# [I 2025-12-04 07:59:55,522] Trial 14 finished with value: 0.7930735930735932 and parameters: {'max_depth': 5, 'learning_rate': 0.08105336112600832, 'random_state': 18}. Best is trial 14 with value: 0.7930735930735932.
# [I 2025-12-04 07:59:58,305] Trial 15 finished with value: 0.7506493506493506 and parameters: {'max_depth': 20, 'learning_rate': 0.08685748799459067, 'random_state': 14}. Best is trial 14 with value: 0.7930735930735932.
# [I 2025-12-04 08:00:01,346] Trial 16 finished with value: 0.7874458874458874 and parameters: {'max_depth': 6, 'learning_rate': 0.10043786499013428, 'random_state': 46}. Best is trial 14 with value: 0.7930735930735932.
# [I 2025-12-04 08:00:04,840] Trial 17 finished with value: 0.769047619047619 and parameters: {'max_depth': 6, 'learning_rate': 0.07847764535083676, 'random_state': 52}. Best is trial 14 with value: 0.7930735930735932.
# [I 2025-12-04 08:00:08,417] Trial 18 finished with value: 0.7506493506493506 and parameters: {'max_depth': 12, 'learning_rate': 0.12216854947417889, 'random_state': 77}. Best is trial 14 with value: 0.7930735930735932.
# [I 2025-12-04 08:00:10,720] Trial 19 finished with value: 0.7640692640692641 and parameters: {'max_depth': 5, 'learning_rate': 0.03470780271658796, 'random_state': 1}. Best is trial 14 with value: 0.7930735930735932.
# [I 2025-12-04 08:00:13,513] Trial 20 finished with value: 0.7506493506493506 and parameters: {'max_depth': 11, 'learning_rate': 0.018169059708299625, 'random_state': 16}. Best is trial 14 with value: 0.7930735930735932.
# [I 2025-12-04 08:00:15,730] Trial 21 finished with value: 0.7696969696969698 and parameters: {'max_depth': 5, 'learning_rate': 0.15202517860509798, 'random_state': 44}. Best is trial 14 with value: 0.7930735930735932.
# [I 2025-12-04 08:00:16,956] Trial 22 finished with value: 0.8075757575757576 and parameters: {'max_depth': 3, 'learning_rate': 0.05524468023849621, 'random_state': 35}. Best is trial 22 with value: 0.8075757575757576.
# [I 2025-12-04 08:00:21,235] Trial 23 finished with value: 0.7833333333333333 and parameters: {'max_depth': 6, 'learning_rate': 0.05113429480114173, 'random_state': 25}. Best is trial 22 with value: 0.8075757575757576.
# [I 2025-12-04 08:00:24,399] Trial 24 finished with value: 0.7456709956709957 and parameters: {'max_depth': 7, 'learning_rate': 0.05643661451724926, 'random_state': 51}. Best is trial 22 with value: 0.8075757575757576.
# [I 2025-12-04 08:00:26,021] Trial 25 finished with value: 0.7746753246753247 and parameters: {'max_depth': 4, 'learning_rate': 0.12467385110959031, 'random_state': 35}. Best is trial 22 with value: 0.8075757575757576.
# [I 2025-12-04 08:00:28,857] Trial 26 finished with value: 0.7554112554112553 and parameters: {'max_depth': 16, 'learning_rate': 0.012697228845518965, 'random_state': 19}. Best is trial 22 with value: 0.8075757575757576.
# [I 2025-12-04 08:00:30,498] Trial 27 finished with value: 0.7794372294372295 and parameters: {'max_depth': 4, 'learning_rate': 0.04848134696433688, 'random_state': 9}. Best is trial 22 with value: 0.8075757575757576.
# [I 2025-12-04 08:00:34,845] Trial 28 finished with value: 0.7218614718614719 and parameters: {'max_depth': 8, 'learning_rate': 0.15121096101956819, 'random_state': 59}. Best is trial 22 with value: 0.8075757575757576.
# [I 2025-12-04 08:00:37,677] Trial 29 finished with value: 0.7928571428571428 and parameters: {'max_depth': 6, 'learning_rate': 0.02481356230658619, 'random_state': 30}. Best is trial 22 with value: 0.8075757575757576.
# [I 2025-12-04 08:00:40,461] Trial 30 finished with value: 0.7601731601731601 and parameters: {'max_depth': 20, 'learning_rate': 0.02076377799231835, 'random_state': 29}. Best is trial 22 with value: 0.8075757575757576.
# [I 2025-12-04 08:00:44,095] Trial 31 finished with value: 0.8023809523809524 and parameters: {'max_depth': 6, 'learning_rate': 0.09241628398183387, 'random_state': 22}. Best is trial 22 with value: 0.8075757575757576.
# [I 2025-12-04 08:00:48,370] Trial 32 finished with value: 0.7406926406926406 and parameters: {'max_depth': 8, 'learning_rate': 0.03726133740115537, 'random_state': 21}. Best is trial 22 with value: 0.8075757575757576.
# [I 2025-12-04 08:00:51,077] Trial 33 finished with value: 0.7645021645021645 and parameters: {'max_depth': 6, 'learning_rate': 0.00996111752916445, 'random_state': 9}. Best is trial 22 with value: 0.8075757575757576.
# [I 2025-12-04 08:00:53,831] Trial 34 finished with value: 0.6426406926406926 and parameters: {'max_depth': 7, 'learning_rate': 0.0010089767083273332, 'random_state': 31}. Best is trial 22 with value: 0.8075757575757576.
# [I 2025-12-04 08:00:55,522] Trial 35 finished with value: 0.7696969696969698 and parameters: {'max_depth': 4, 'learning_rate': 0.02675223244075071, 'random_state': 21}. Best is trial 22 with value: 0.8075757575757576.
# [I 2025-12-04 08:00:58,579] Trial 36 finished with value: 0.7642857142857142 and parameters: {'max_depth': 9, 'learning_rate': 0.06269629470041531, 'random_state': 24}. Best is trial 22 with value: 0.8075757575757576.
# [I 2025-12-04 08:01:01,974] Trial 37 finished with value: 0.7831168831168831 and parameters: {'max_depth': 5, 'learning_rate': 0.04048236373996551, 'random_state': 6}. Best is trial 22 with value: 0.8075757575757576.
# [I 2025-12-04 08:01:04,957] Trial 38 finished with value: 0.7311688311688311 and parameters: {'max_depth': 8, 'learning_rate': 0.026211552112277128, 'random_state': 36}. Best is trial 22 with value: 0.8075757575757576.
# [I 2025-12-04 08:01:06,168] Trial 39 finished with value: 0.8025974025974026 and parameters: {'max_depth': 3, 'learning_rate': 0.1826489931171561, 'random_state': 86}. Best is trial 22 with value: 0.8075757575757576.
# [I 2025-12-04 08:01:07,355] Trial 40 finished with value: 0.7738095238095237 and parameters: {'max_depth': 3, 'learning_rate': 0.18006562299678772, 'random_state': 93}. Best is trial 22 with value: 0.8075757575757576.
# [I 2025-12-04 08:01:09,084] Trial 41 finished with value: 0.7746753246753247 and parameters: {'max_depth': 4, 'learning_rate': 0.06969297702349433, 'random_state': 87}. Best is trial 22 with value: 0.8075757575757576.
# [I 2025-12-04 08:01:12,811] Trial 42 finished with value: 0.7454545454545455 and parameters: {'max_depth': 7, 'learning_rate': 0.10877296326135544, 'random_state': 100}. Best is trial 22 with value: 0.8075757575757576.
# [I 2025-12-04 08:01:15,809] Trial 43 finished with value: 0.7642857142857142 and parameters: {'max_depth': 5, 'learning_rate': 0.008097178731454572, 'random_state': 79}. Best is trial 22 with value: 0.8075757575757576.
# [I 2025-12-04 08:01:17,017] Trial 44 finished with value: 0.7974025974025973 and parameters: {'max_depth': 3, 'learning_rate': 0.2741815581541724, 'random_state': 42}. Best is trial 22 with value: 0.8075757575757576.
# [I 2025-12-04 08:01:18,216] Trial 45 finished with value: 0.7926406926406926 and parameters: {'max_depth': 3, 'learning_rate': 0.28346606609928454, 'random_state': 40}. Best is trial 22 with value: 0.8075757575757576.
# [I 2025-12-04 08:01:19,432] Trial 46 finished with value: 0.7928571428571429 and parameters: {'max_depth': 3, 'learning_rate': 0.1963532016713611, 'random_state': 59}. Best is trial 22 with value: 0.8075757575757576.
# [I 2025-12-04 08:01:21,084] Trial 47 finished with value: 0.764935064935065 and parameters: {'max_depth': 4, 'learning_rate': 0.1518850263148106, 'random_state': 68}. Best is trial 22 with value: 0.8075757575757576.
# [I 2025-12-04 08:01:23,464] Trial 48 finished with value: 0.7885281385281385 and parameters: {'max_depth': 5, 'learning_rate': 0.2979627960300405, 'random_state': 55}. Best is trial 22 with value: 0.8075757575757576.
# [I 2025-12-04 08:01:24,827] Trial 49 finished with value: 0.8073593073593074 and parameters: {'max_depth': 3, 'learning_rate': 0.0930915052357559, 'random_state': 42}. Best is trial 22 with value: 0.8075757575757576.

# %%
best_params = study.best_params
print(f"Best Parameters found: {best_params}")
# Out:
# Best Parameters found: {'max_depth': 3, 'learning_rate': 0.05524468023849621, 'random_state': 35}

# %%
# 3. Retrain Model with Best Parameters
best_gb = GradientBoostingClassifier(
    max_depth=best_params['max_depth'],
    learning_rate=best_params['learning_rate'],
    random_state=best_params['random_state']
)
best_gb.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(learning_rate=0.05524468023849621, random_state=35)

# %%
# 4. Evaluate on Training Data
y_train_pred = best_gb.predict(X_train)
train_acc = accuracy_score(y_train, y_train_pred)
train_prec = precision_score(y_train, y_train_pred)
train_rec = recall_score(y_train, y_train_pred)
train_f1 = f1_score(y_train, y_train_pred)

# 5. Evaluate on Test Data
y_test_pred = best_gb.predict(X_test)
test_acc = accuracy_score(y_test, y_test_pred)
test_prec = precision_score(y_test, y_test_pred)
test_rec = recall_score(y_test, y_test_pred)
test_f1 = f1_score(y_test, y_test_pred)

# %%
# 6. Print Results
print("Training Set Metrics:")
print(f"  Accuracy:  {train_acc * 100:.2f}%")
print(f"  Precision: {train_prec * 100:.2f}%")
print(f"  Recall:    {train_rec * 100:.2f}%")
print(f"  F1 Score:  {train_f1 * 100:.2f}%")

print("Test Set Metrics:")
print(f"  Accuracy:  {test_acc * 100:.2f}%")
print(f"  Precision: {test_prec * 100:.2f}%")
print(f"  Recall:    {test_rec * 100:.2f}%")
print(f"  F1 Score:  {test_f1 * 100:.2f}%")
# Out:
# Training Set Metrics:
#   Accuracy:  98.58%
#   Precision: 98.95%
#   Recall:    97.92%
#   F1 Score:  98.43%
# Test Set Metrics:
#   Accuracy:  81.32%
#   Precision: 82.50%
#   Recall:    76.74%
#   F1 Score:  79.52%

# %%
# 7. Visualization of Confusion Matrix
cm = confusion_matrix(y_test, y_test_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['No Disease', 'Disease'],
            yticklabels=['No Disease', 'Disease'])

plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix of Tuned Gradient Boosting')
plt.show()

# %%
# 8. Visualization: Feature Importance
# Get importance from the trained model
importances = best_gb.feature_importances_
feature_names = X_train.columns

# Create a DataFrame for easy sorting and plotting
importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

# Plot the Top Features
plt.figure(figsize=(10, 8))
sns.barplot(x='Importance', y='Feature', hue='Feature', data=importance_df, palette='viridis', legend=False)
plt.title('Feature Importance of Tuned Gradient Boosting Model')
plt.xlabel('Importance Score')
plt.ylabel('Features')
plt.show()
